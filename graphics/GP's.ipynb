# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern, ConstantKernel as C

np.random.seed(1)

# %%
# Plotting Draws From GP with Gaussian RBF Kernel

# Input Values
x = np.atleast_2d(np.linspace(0, 10, 1000)).T

# Initializing kernel
kernel = C(1.0, (1e-3, 1e3)) * RBF(1.5, (1e-2, 1e2))

# Intializing GP
gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)

# Drawing sample from a GP
sample = gp.sample_y(x, n_samples=5, random_state=0)

# Plotting Samples from the GP
plt.figure(figsize=(15,8))
plt.plot(x, sample)
plt.xlabel('x',fontsize=20)
plt.ylabel('f(x)',fontsize=20)
# Out:
# Text(0, 0.5, 'f(x)')

# %%
def f1(x):
    """The function to predict."""
    return np.sin(x)*x

# %%
X1 = np.atleast_2d([3., 8.]).T

# Observations
y1 = f1(X1).ravel()

# Mesh the input space for evaluations of the real function, the prediction and
# its MSE
x = np.atleast_2d(np.linspace(0, 10, 1000)).T

# %%
# Instantiate a Gaussian Process model
kernel1 = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))
gp1 = GaussianProcessRegressor(kernel=kernel1, n_restarts_optimizer=9)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp1.fit(X1, y1)

# Make the prediction on the meshed x-axis (ask for MSE as well)
#y_pred_1, sigma1 = gp1.predict(x, return_std=True)
#y_pred_11, sigma11 = gp1.predict(x, return_std=True)
#y_pred_2, sigma2 = gp2.predict(x, return_std=True)
#y_pred_3, sigma3 = gp3.predict(x, return_std=True)
#y_pred_4, sigma4 = gp4.predict(x, return_std=True
                               
# Drawing sample from a GP
sample = gp1.sample_y(x, n_samples=5, random_state=0)

# %%
# Plot the function, the prediction and the 95% confidence interval based on
plt.figure(figsize=(15,8))
#plt.plot(X1, y1, 'k.', markersize=10, label='Observations')
plt.plot(x, sample, label='Prediction')
plt.xlabel('x',fontsize=20)
plt.ylabel('f(x)',fontsize=20)
#ax[0,0].plot(x, y_pred_11, 'b-', label='Prediction')
#ax[0,0].fill(np.concatenate([x, x[::-1]]),
#         np.concatenate([y_pred_1 - 1.9600 * sigma1,
#                        (y_pred_1 + 1.9600 * sigma1)[::-1]]),
#         alpha=.2, fc='r', ec='None', label='95% confidence interval')
